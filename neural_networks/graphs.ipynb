# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("loss_values_gates.csv",header=None)
df.head()
# Out:
#           0
# 0  0.000000
# 1  0.135309
# 2  0.133370
# 3  0.132051
# 4  0.131202

# %%
df.columns = ["Loss function"]

# %%
df.head()
# Out:
#    Loss function
# 0       0.000000
# 1       0.135309
# 2       0.133370
# 3       0.132051
# 4       0.131202

# %%
len(df["Loss function"])
# Out:
# 5001

# %%
X = [x for x in range(len(df))]
y = df['Loss function'].sort_values(ascending=False)

# %%
y.head()
# Out:
# 164    0.160090
# 165    0.160090
# 163    0.160089
# 166    0.160089
# 162    0.160087
# Name: Loss function, dtype: float64

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=X, y=y, c=df['Loss function'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
